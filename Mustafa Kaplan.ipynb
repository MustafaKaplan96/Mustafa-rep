# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mustafa Kaplan**
# Data Scientist

# %% [markdown]
# *I am interested in Data science because data is a powerful tool that enables us to get insights and answer questions and find questions that were not asked. Making decisions is not an easy task, and for individuals and businesses, making the right decisions saves resources.*

# %% [markdown]
# ### My code welcomes you as a reader by your name

# %%
name = input("Please Enter your name:\n")
print("Thanks for your review",name.upper())

# %% [markdown]
# 1. one
# 2. two
# 3. three
#
# - python
# - SQL
# - BI
#
#
# > This is block quoting
# >> This is more text
# >>> and this is more
